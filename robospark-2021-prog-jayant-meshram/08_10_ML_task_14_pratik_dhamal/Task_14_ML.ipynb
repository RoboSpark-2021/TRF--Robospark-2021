# %%
import pandas as pd       
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("dementia_data.csv")
df
# Out:
#     Subject ID         MRI ID        Group  Visit  ...  MMSE  eTIV   nWBV    ASF
# 0    OAS2_0001  OAS2_0001_MR1  Nondemented      1  ...  27.0  1987  0.696  0.883
# 1    OAS2_0001  OAS2_0001_MR2  Nondemented      2  ...  30.0  2004  0.681  0.876
# 2    OAS2_0002  OAS2_0002_MR1     Demented      1  ...  23.0  1678  0.736  1.046
# 3    OAS2_0002  OAS2_0002_MR2     Demented      2  ...  28.0  1738  0.713  1.010
# 4    OAS2_0002  OAS2_0002_MR3     Demented      3  ...  22.0  1698  0.701  1.034
# ..         ...            ...          ...    ...  ...   ...   ...    ...    ...
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2  ...  28.0  1693  0.694  1.037
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3  ...  26.0  1688  0.675  1.040
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1  ...  30.0  1319  0.801  1.331
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2  ...  30.0  1327  0.796  1.323
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3  ...  30.0  1333  0.801  1.317
#
# [373 rows x 13 columns]

# %%
df_copy=df.copy()
vis_copy=df.copy()

# %%
df['Group']=np.where(df['Group']=='Demented',1,0)
df['M/F']=np.where(df['M/F']=='M',1,0)
df
# Out:
#     Subject ID         MRI ID  Group  Visit  ...  MMSE  eTIV   nWBV    ASF
# 0    OAS2_0001  OAS2_0001_MR1      0      1  ...  27.0  1987  0.696  0.883
# 1    OAS2_0001  OAS2_0001_MR2      0      2  ...  30.0  2004  0.681  0.876
# 2    OAS2_0002  OAS2_0002_MR1      1      1  ...  23.0  1678  0.736  1.046
# 3    OAS2_0002  OAS2_0002_MR2      1      2  ...  28.0  1738  0.713  1.010
# 4    OAS2_0002  OAS2_0002_MR3      1      3  ...  22.0  1698  0.701  1.034
# ..         ...            ...    ...    ...  ...   ...   ...    ...    ...
# 368  OAS2_0185  OAS2_0185_MR2      1      2  ...  28.0  1693  0.694  1.037
# 369  OAS2_0185  OAS2_0185_MR3      1      3  ...  26.0  1688  0.675  1.040
# 370  OAS2_0186  OAS2_0186_MR1      0      1  ...  30.0  1319  0.801  1.331
# 371  OAS2_0186  OAS2_0186_MR2      0      2  ...  30.0  1327  0.796  1.323
# 372  OAS2_0186  OAS2_0186_MR3      0      3  ...  30.0  1333  0.801  1.317
#
# [373 rows x 13 columns]

# %%
x=vis_copy['M/F'].unique()
y=vis_copy['M/F'].value_counts(dropna=True).sort_index(ascending=True)
plt.bar(x,y,color=['r','g'])

plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Count of males and females")
# Out:
# Text(0.5, 1.0, 'Count of males and females')
