# %%
import pandas as pd       # dataframe operations 
import numpy as np 
import seaborn as sb
import matplotlib.pyplot as mp

# %%
path = '/content/HRDataset_v14.csv'

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#                 Employee_Name  EmpID  ...  DaysLateLast30  Absences
# 0         Adinolfi, Wilson  K  10026  ...               0         1
# 1    Ait Sidi, Karthikeyan     10084  ...               0        17
# 2           Akinkuolie, Sarah  10196  ...               0         3
# 3                Alagbe,Trina  10088  ...               0        15
# 4            Anderson, Carol   10069  ...               0         2
# ..                        ...    ...  ...             ...       ...
# 306            Woodson, Jason  10135  ...               0        13
# 307        Ybarra, Catherine   10301  ...               5         4
# 308          Zamora, Jennifer  10010  ...               0        16
# 309               Zhou, Julia  10043  ...               0        11
# 310             Zima, Colleen  10271  ...               0         2
#
# [311 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
df.drop(['Employee_Name','EmpID'], axis='columns', inplace=True)

# %%
df['RecruitmentSource'].value_counts()
# Out:
# Indeed                     87
# LinkedIn                   76
# Google Search              49
# Employee Referral          31
# Diversity Job Fair         29
# CareerBuilder              23
# Website                    13
# Other                       2
# On-line Web application     1
# Name: RecruitmentSource, dtype: int64

# %%
df['RecruitmentSource'].isna().sum()
# Out:
# 0

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()
df['RecruitmentSource']= label_encoder.fit_transform(df['RecruitmentSource'])
# df['RecruitmentSource']
# onehotEnc = preprocessing.OneHotEncoder()
# onehotEnc.fit(df['RecruitmentSource'].reshape(-1, 1))
# targets_trans = onehotEnc.transform(new_target.reshape(-1, 1)) #hot encoding karna hai

# %%
df
# Out:
#      MarriedID  MaritalStatusID  ...  DaysLateLast30  Absences
# 0            0                0  ...               0         1
# 1            1                1  ...               0        17
# 2            1                1  ...               0         3
# 3            1                1  ...               0        15
# 4            0                2  ...               0         2
# ..         ...              ...  ...             ...       ...
# 306          0                0  ...               0        13
# 307          0                0  ...               5         4
# 308          0                0  ...               0        16
# 309          0                0  ...               0        11
# 310          0                4  ...               0         2
#
# [311 rows x 34 columns]

# %%
df.drop(['LastPerformanceReview_Date'], axis='columns', inplace=True)

# %%
df['PerformanceScore'].isna().sum()
# Out:
# 0

# %%
df['PerformanceScore'].value_counts()
# Out:
# Fully Meets          243
# Exceeds               37
# Needs Improvement     18
# PIP                   13
# Name: PerformanceScore, dtype: int64

# %%
df['PerformanceScore'].value_counts()
# Out:
# Fully Meets          243
# Exceeds               37
# Needs Improvement     18
# PIP                   13
# Name: PerformanceScore, dtype: int64

# %%
df
# Out:
#      MarriedID  MaritalStatusID  ...  DaysLateLast30  Absences
# 0            0                0  ...               0         1
# 1            1                1  ...               0        17
# 2            1                1  ...               0         3
# 3            1                1  ...               0        15
# 4            0                2  ...               0         2
# ..         ...              ...  ...             ...       ...
# 306          0                0  ...               0        13
# 307          0                0  ...               5         4
# 308          0                0  ...               0        16
# 309          0                0  ...               0        11
# 310          0                4  ...               0         2
#
# [311 rows x 33 columns]

# %%
df.corr()
# Out:
#                         MarriedID  MaritalStatusID  ...  DaysLateLast30  Absences
# MarriedID                1.000000         0.164044  ...        0.002875  0.096086
# MaritalStatusID          0.164044         1.000000  ...       -0.096500  0.018722
# GenderID                -0.024199        -0.030236  ...        0.080329 -0.004577
# EmpStatusID              0.085619         0.114630  ...        0.078318  0.091834
# DeptID                  -0.119932         0.012768  ...        0.124630  0.053308
# PerfScoreID             -0.058362         0.044693  ...       -0.734728  0.046629
# FromDiversityJobFairID  -0.012708         0.041117  ...        0.042532  0.062640
# Salary                   0.026165        -0.070291  ...       -0.069443  0.082382
# Termd                    0.077028         0.099367  ...        0.136379  0.098274
# PositionID              -0.027334         0.021923  ...       -0.004040 -0.071434
# ...

# %%
df['ManagerName'].value_counts()

# %%
df.drop(['ManagerName'], axis='columns', inplace=True)

# %%
df['PerformanceScore']= label_encoder.fit_transform(df['PerformanceScore'])

# %%
PerfScoreID = df['PerfScoreID'].value_counts().iloc[:10]

mp.figure(figsize=(10,5))
sb.barplot(x = PerfScoreID.index , y = PerfScoreID.values ,order=PerfScoreID.index, palette='rocket')

mp.title('sum employees in each Perf Score ID' , fontsize=20)
mp.xticks(fontsize=15)
mp.yticks(fontsize=15)

mp.show()

# %%
Sex = df['Sex'].value_counts()

mp.figure(figsize=(10,5))
sb.barplot(x = Sex.index , y=Sex.values , order = Sex.index, palette='rocket')

mp.title(' Sex'  , fontsize=20)

mp.xticks(fontsize=15)
mp.yticks(fontsize=15)

mp.show()

# %%
EngagementSurvey = df['EngagementSurvey'].value_counts().iloc[:20]


mp.figure(figsize=(14,5))
sb.barplot(x = EngagementSurvey.index , y=EngagementSurvey.values , order=EngagementSurvey.index , palette='rocket')

mp.title('Engagement Survey ' , fontsize=20)
mp.xticks(fontsize=15)

mp.yticks(fontsize=15)

mp.show()

# %%
col = df['PerformanceScore'].value_counts()
mp.figure(figsize=(10,12))

sb.barplot(x = col.values , y=col.index , order = col.index, palette='rocket')

mp.title('Performance Score' , fontsize=20)
mp.xticks(fontsize=15)
mp.yticks(fontsize=15)
mp.show()

# %%
cols = ['Salary','Termd' ,'EngagementSurvey','EmpSatisfaction','Absences']
for i in cols:
    mp.figure(figsize=(5,5))
    sb.boxplot(y=df[i])
    mp.title(i)
    mp.show()

# %%
# df['State'].value_counts()

# %%
df.corr()

# %%
df

# %%
df['Sex']= label_encoder.fit_transform(df['Sex'])

# %%
df.drop(['DOB'],axis='columns' ,inplace=True)

# %%
df.isna().sum()

# %%
df.drop(['DateofTermination'],axis='columns' ,inplace=True)

# %%
df['EmploymentStatus'].value_counts()

# %%
df['EmploymentStatus']= label_encoder.fit_transform(df['EmploymentStatus'])

# %%
df['TermReason'].value_counts()

# %%
df['TermReason']= label_encoder.fit_transform(df['TermReason']) 
df['RaceDesc']= label_encoder.fit_transform(df['RaceDesc']) 
df['HispanicLatino']= label_encoder.fit_transform(df['HispanicLatino']) 
df['MaritalDesc']= label_encoder.fit_transform(df['MaritalDesc']) 
df['CitizenDesc']= label_encoder.fit_transform(df['CitizenDesc'])

# %%
df

# %%
df.drop(['Position'],axis='columns' ,inplace=True)

# %%
df.drop(['Sex'],axis='columns' ,inplace=True)

# %%
df.drop(['State','Zip'],axis='columns' ,inplace=True)

# %%
df

# %%
df.drop(['Department'],axis='columns' ,inplace=True)

# %%
df.drop(['DateofHire'],axis='columns' ,inplace=True)

# %%
corfeatures=correlation(df,.80)
corfeatures

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
bestfeatures=SelectKBest(score_func=chi2,k=18)

# %%
df.corr()

# %%
import seaborn as sb
import matplotlib.pyplot as mp

# %%
sb.set(rc = {'figure.figsize':(16,9)})
sb.heatmap(df.corr(), vmin = -1, vmax = +1, annot = True, cmap = 'coolwarm')
  
# displaying heatmap

# %%
y=df['PerformanceScore']
#5,7,18,19,20,21
X = df.iloc[:,[7,8,18,19,20,21]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=10)

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rfg=RandomForestClassifier(random_state=33,n_estimators=23)
parameters=[{'min_samples_split':[2,3,4,5],'criterion':['gini','entropy'],'min_samples_leaf':[1,2,3]}]

model_gridrf=GridSearchCV(estimator=classifier_rfg, param_grid=parameters, scoring='accuracy',cv=10)
model_gridrf.fit(X_train,y_train)

# %%
from sklearn.naive_bayes import BernoulliNB
model_nb = BernoulliNB()
model_nb.fit(X_train,y_train)

# %%
y_predict = model_nb.predict(X_test)

# %%
y_predicttr=model_nb.predict(X_train)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
cm = confusion_matrix(y_test, y_predict)
print(cm)
print(accuracy_score(y_test,y_predict))
